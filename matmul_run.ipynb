# %% [markdown]
# ## This file is used to run bash files that measure power consumption of different experiment runs

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !nvcc -V
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Wed_Sep_21_10:33:58_PDT_2022
# Cuda compilation tools, release 11.8, V11.8.89
# Build cuda_11.8.r11.8/compiler.31833905_0

# %%
# !nvidia-smi
# Out:
# Mon Apr 24 16:17:26 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.85.12    Driver Version: 525.85.12    CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# %cd /content/drive/MyDrive/
# !git clone https://github.com/xpeng000/matmul-pwr.git
# Out:
# /content/drive/MyDrive
# Cloning into 'matmul-pwr'...
# remote: Enumerating objects: 46, done.
# remote: Counting objects: 100% (46/46), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 46 (delta 10), reused 35 (delta 7), pack-reused 0
# Unpacking objects: 100% (46/46), 398.46 KiB | 786.00 KiB/s, done.

# %%
# %cd /content/drive/MyDrive/matmul-pwr
# !ls
# Out:
# /content/drive/MyDrive/matmul-pwr
# common.h  data	matmul.cu  mm  plot  README.md	record_all.sh  record.sh

# %%
# !bash ./record.sh > ./data/gpu_pwr_plain_T4_0_50_9.txt

# %%
# !bash ./record.sh > ./data/gpu_pwr_plain_T4_0_50_10.txt

# %%
# !bash ./record.sh > ./data/gpu_pwr_plain_T4_0_50_11.txt

# %%
# !bash ./record.sh > ./data/gpu_pwr_naive_T4_0_50_9.txt

# %%
# !bash ./record.sh > ./data/gpu_pwr_naive_T4_0_50_10.txt

# %%
# !bash ./record.sh > ./data/gpu_pwr_naive_T4_0_50_11.txt

# %%
# !bash ./record.sh > ./data/gpu_pwr_coalesced_T4_0_50_9.txt

# %%
# !bash ./record.sh > ./data/gpu_pwr_coalesced_T4_0_50_10.txt

# %%
# !bash ./record.sh > ./data/gpu_pwr_coalesced_T4_0_50_11.txt
